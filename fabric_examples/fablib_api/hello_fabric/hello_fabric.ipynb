# %% [markdown]
# # Hello, FABRIC: Create Your First FABRIC Experiment
#
# This Jupyter notebook will walk you through creating your first FABRIC experiment. The "Hello, FABRIC" experiment tests the configuration of your environment to ensure you can create and access resources on FABRIC.  Specifically, the experiment deploys a slice of resources with a single virtual machine and confirms you can log into the virtual machine using FABLib methods.
#
# ### FABlib API References
#
# - [fablib.show_config](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.show_config)
# - [fablib.list_sites](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.list_sites)
# - [fablib.new_slice](https://fabric-fablib.readthedocs.io/en/latest/fablib.html#fabrictestbed_extensions.fablib.fablib.FablibManager.new_slice)
# - [slice.add_node](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.add_node)
# - [slice.submit](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.submit)
# - [slice.get_nodes](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.get_nodes)
# - [slice.list_nodes](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.list_nodesß)
# - [slice.show](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.show)
# - [node.execute](https://fabric-fablib.readthedocs.io/en/latest/node.html#fabrictestbed_extensions.fablib.node.Node.execute)
# - [slice.delete](https://fabric-fablib.readthedocs.io/en/latest/slice.html#fabrictestbed_extensions.fablib.slice.Slice.delete)
#
#
# ## Step 1:  Configure the Environment
#
# Before running this notebook, you will need to configure your environment using the [Configure Environment](../../../configure_and_validate.ipynb) notebook. Please stop here, open and run that notebook, then return to this notebook.
#
# If you are using the FABRIC JupyterHub many of the environment variables will be automatically configured for you.  You will still need to set your bastion username, upload your bastion private key, and set the path to where you put your bastion private key. Your bastion username and private key should already be in your possession.
#
# If you are using the FABRIC API outside of the JupyterHub you will need to configure all of the environment variables. Defaults below will be correct in many situations but you will need to confirm your configuration.  If you have questions about this configuration, please contact the FABRIC admins using the [FABRIC User Forum](https://learn.fabric-testbed.net/forums/)
#
# More information about accessing your experiments through the FABRIC bastion hosts can be found [here](https://learn.fabric-testbed.net/knowledge-base/logging-into-fabric-vms/).

# %% [markdown]
# ## Step 2: Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

fablib.show_config();
# Out:
# User: lngo@wcupa.edu bastion key is valid!
# Configuration is valid
# <style type="text/css">
# #T_bfcd9 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bfcd9 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bfcd9 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_bfcd9_row0_col0, #T_bfcd9_row0_col1, #T_bfcd9_row1_col0, #T_bfcd9_row1_col1, #T_bfcd9_row2_col0, #T_bfcd9_row2_col1, #T_bfcd9_row3_col0, #T_bfcd9_row3_col1, #T_bfcd9_row4_col0, #T_bfcd9_row4_col1, #T_bfcd9_row5_col0, #T_bfcd9_row5_col1, #T_bfcd9_row6_col0, #T_bfcd9_row6_col1, #T_bfcd9_row7_col0, #T_bfcd9_row7_col1, #T_bfcd9_row8_col0, #T_bfcd9_row8_col1, #T_bfcd9_row9_col0, #T_bfcd9_row9_col1, #T_bfcd9_row10_col0, #T_bfcd9_row10_col1, #T_bfcd9_row11_col0, #T_bfcd9_row11_col1, #T_bfcd9_row12_col0, #T_bfcd9_row12_col1, #T_bfcd9_row13_col0, #T_bfcd9_row13_col1, #T_bfcd9_row14_col0, #T_bfcd9_row14_col1, #T_bfcd9_row15_col0, #T_bfcd9_row15_col1, #T_bfcd9_row16_col0, #T_bfcd9_row16_col1, #T_bfcd9_row17_col0, #T_bfcd9_row17_col1, #T_bfcd9_row18_col0, #T_bfcd9_row18_col1, #T_bfcd9_row19_col0, #T_bfcd9_row19_col1, #T_bfcd9_row20_col0, #T_bfcd9_row20_col1, #T_bfcd9_row21_col0, #T_bfcd9_row21_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_bfcd9">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bfcd9_row0_col0" class="data row0 col0" >Log Level</td>
#       <td id="T_bfcd9_row0_col1" class="data row0 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row1_col0" class="data row1 col0" >Log File</td>
#       <td id="T_bfcd9_row1_col1" class="data row1 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row2_col0" class="data row2 col0" >Log Propagate</td>
#       <td id="T_bfcd9_row2_col1" class="data row2 col1" >False</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row3_col0" class="data row3 col0" >Data directory</td>
#       <td id="T_bfcd9_row3_col1" class="data row3 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row4_col0" class="data row4 col0" >Orchestrator</td>
#       <td id="T_bfcd9_row4_col1" class="data row4 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row5_col0" class="data row5 col0" >Credential Manager</td>
#       <td id="T_bfcd9_row5_col1" class="data row5 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row6_col0" class="data row6 col0" >Core API</td>
#       <td id="T_bfcd9_row6_col1" class="data row6 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row7_col0" class="data row7 col0" >Artifact Manager</td>
#       <td id="T_bfcd9_row7_col1" class="data row7 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row8_col0" class="data row8 col0" >CEPH Manager</td>
#       <td id="T_bfcd9_row8_col1" class="data row8 col1" >https://ceph-mgr.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row9_col0" class="data row9 col0" >Token File</td>
#       <td id="T_bfcd9_row9_col1" class="data row9 col1" >/home/fabric/.fabric/token.json</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row10_col0" class="data row10 col0" >Project ID</td>
#       <td id="T_bfcd9_row10_col1" class="data row10 col1" >8b6dfc51-02ad-4f00-a389-6e75d8b61a26</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row11_col0" class="data row11 col0" >Bastion Host</td>
#       <td id="T_bfcd9_row11_col1" class="data row11 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row12_col0" class="data row12 col0" >Bastion Username</td>
#       <td id="T_bfcd9_row12_col1" class="data row12 col1" >lngo_0000005935</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row13_col0" class="data row13 col0" >Bastion Private Key File</td>
#       <td id="T_bfcd9_row13_col1" class="data row13 col1" >/home/fabric/.ssh/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row14_col0" class="data row14 col0" >Version</td>
#       <td id="T_bfcd9_row14_col1" class="data row14 col1" >2.0.2</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row15_col0" class="data row15 col0" >Slice Public Key File</td>
#       <td id="T_bfcd9_row15_col1" class="data row15 col1" >/home/fabric/.ssh/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row16_col0" class="data row16 col0" >Slice Private Key File</td>
#       <td id="T_bfcd9_row16_col1" class="data row16 col1" >/home/fabric/.ssh/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row17_col0" class="data row17 col0" >Sites to avoid</td>
#       <td id="T_bfcd9_row17_col1" class="data row17 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row18_col0" class="data row18 col0" >SSH Command Line</td>
#       <td id="T_bfcd9_row18_col1" class="data row18 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row19_col0" class="data row19 col0" >Bastion SSH Config File</td>
#       <td id="T_bfcd9_row19_col1" class="data row19 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row20_col0" class="data row20 col0" >Fabric Meta Data Release Tag</td>
#       <td id="T_bfcd9_row20_col1" class="data row20 col1" >main</td>
#     </tr>
#     <tr>
#       <td id="T_bfcd9_row21_col0" class="data row21 col0" >Project Name</td>
#       <td id="T_bfcd9_row21_col1" class="data row21 col1" >cloud-edu</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3 (Optional): Query for Available Testbed Resources and Settings
#
# This optional command queries the FABRIC services to find the available resources. It may be useful for finding a site with available capacity.

# %%
fablib.list_sites();
# Out:
# <style type="text/css">
# #T_f99f5 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_f99f5 th {
#   text-align: left;
# }
# #T_f99f5 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f99f5 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f99f5 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f99f5_row0_col0, #T_f99f5_row0_col1, #T_f99f5_row0_col2, #T_f99f5_row0_col3, #T_f99f5_row0_col4, #T_f99f5_row0_col5, #T_f99f5_row0_col6, #T_f99f5_row0_col7, #T_f99f5_row0_col8, #T_f99f5_row0_col9, #T_f99f5_row0_col10, #T_f99f5_row0_col11, #T_f99f5_row0_col12, #T_f99f5_row0_col13, #T_f99f5_row0_col14, #T_f99f5_row0_col15, #T_f99f5_row0_col16, #T_f99f5_row0_col17, #T_f99f5_row0_col18, #T_f99f5_row0_col19, #T_f99f5_row0_col20, #T_f99f5_row0_col21, #T_f99f5_row0_col22, #T_f99f5_row0_col23, #T_f99f5_row0_col24, #T_f99f5_row0_col25, #T_f99f5_row0_col26, #T_f99f5_row0_col27, #T_f99f5_row0_col28, #T_f99f5_row0_col29, #T_f99f5_row0_col30, #T_f99f5_row0_col31, #T_f99f5_row0_col32, #T_f99f5_row0_col33, #T_f99f5_row0_col34, #T_f99f5_row0_col35, #T_f99f5_row0_col36, #T_f99f5_row0_col37, #T_f99f5_row0_col38, #T_f99f5_row0_col39, #T_f99f5_row0_col40, #T_f99f5_row0_col41, #T_f99f5_row0_col42, #T_f99f5_row0_col43, #T_f99f5_row0_col44, #T_f99f5_row0_col45, #T_f99f5_row0_col46, #T_f99f5_row0_col47, #T_f99f5_row0_col48, #T_f99f5_row0_col49, #T_f99f5_row0_col50, #T_f99f5_row0_col51, #T_f99f5_row0_col52, #T_f99f5_row0_col53, #T_f99f5_row0_col54, #T_f99f5_row0_col55, #T_f99f5_row0_col56, #T_f99f5_row0_col57, #T_f99f5_row1_col0, #T_f99f5_row1_col1, #T_f99f5_row1_col2, #T_f99f5_row1_col3, #T_f99f5_row1_col4, #T_f99f5_row1_col5, #T_f99f5_row1_col6, #T_f99f5_row1_col7, #T_f99f5_row1_col8, #T_f99f5_row1_col9, #T_f99f5_row1_col10, #T_f99f5_row1_col11, #T_f99f5_row1_col12, #T_f99f5_row1_col13, #T_f99f5_row1_col14, #T_f99f5_row1_col15, #T_f99f5_row1_col16, #T_f99f5_row1_col17, #T_f99f5_row1_col18, #T_f99f5_row1_col19, #T_f99f5_row1_col20, #T_f99f5_row1_col21, #T_f99f5_row1_col22, #T_f99f5_row1_col23, #T_f99f5_row1_col24, #T_f99f5_row1_col25, #T_f99f5_row1_col26, #T_f99f5_row1_col27, #T_f99f5_row1_col28, #T_f99f5_row1_col29, #T_f99f5_row1_col30, #T_f99f5_row1_col31, #T_f99f5_row1_col32, #T_f99f5_row1_col33, #T_f99f5_row1_col34, #T_f99f5_row1_col35, #T_f99f5_row1_col36, #T_f99f5_row1_col37, #T_f99f5_row1_col38, #T_f99f5_row1_col39, #T_f99f5_row1_col40, #T_f99f5_row1_col41, #T_f99f5_row1_col42, #T_f99f5_row1_col43, #T_f99f5_row1_col44, #T_f99f5_row1_col45, #T_f99f5_row1_col46, #T_f99f5_row1_col47, #T_f99f5_row1_col48, #T_f99f5_row1_col49, #T_f99f5_row1_col50, #T_f99f5_row1_col51, #T_f99f5_row1_col52, #T_f99f5_row1_col53, #T_f99f5_row1_col54, #T_f99f5_row1_col55, #T_f99f5_row1_col56, #T_f99f5_row1_col57, #T_f99f5_row2_col0, #T_f99f5_row2_col1, #T_f99f5_row2_col2, #T_f99f5_row2_col3, #T_f99f5_row2_col4, #T_f99f5_row2_col5, #T_f99f5_row2_col6, #T_f99f5_row2_col7, #T_f99f5_row2_col8, #T_f99f5_row2_col9, #T_f99f5_row2_col10, #T_f99f5_row2_col11, #T_f99f5_row2_col12, #T_f99f5_row2_col13, #T_f99f5_row2_col14, #T_f99f5_row2_col15, #T_f99f5_row2_col16, #T_f99f5_row2_col17, #T_f99f5_row2_col18, #T_f99f5_row2_col19, #T_f99f5_row2_col20, #T_f99f5_row2_col21, #T_f99f5_row2_col22, #T_f99f5_row2_col23, #T_f99f5_row2_col24, #T_f99f5_row2_col25, #T_f99f5_row2_col26, #T_f99f5_row2_col27, #T_f99f5_row2_col28, #T_f99f5_row2_col29, #T_f99f5_row2_col30, #T_f99f5_row2_col31, #T_f99f5_row2_col32, #T_f99f5_row2_col33, #T_f99f5_row2_col34, #T_f99f5_row2_col35, #T_f99f5_row2_col36, #T_f99f5_row2_col37, #T_f99f5_row2_col38, #T_f99f5_row2_col39, #T_f99f5_row2_col40, #T_f99f5_row2_col41, #T_f99f5_row2_col42, #T_f99f5_row2_col43, #T_f99f5_row2_col44, #T_f99f5_row2_col45, #T_f99f5_row2_col46, #T_f99f5_row2_col47, #T_f99f5_row2_col48, #T_f99f5_row2_col49, #T_f99f5_row2_col50, #T_f99f5_row2_col51, #T_f99f5_row2_col52, #T_f99f5_row2_col53, #T_f99f5_row2_col54, #T_f99f5_row2_col55, #T_f99f5_row2_col56, #T_f99f5_row2_col57, #T_f99f5_row3_col0, #T_f99f5_row3_col1, #T_f99f5_row3_col2, #T_f99f5_row3_col3, #T_f99f5_row3_col4, #T_f99f5_row3_col5, #T_f99f5_row3_col6, #T_f99f5_row3_col7, #T_f99f5_row3_col8, #T_f99f5_row3_col9, #T_f99f5_row3_col10, #T_f99f5_row3_col11, #T_f99f5_row3_col12, #T_f99f5_row3_col13, #T_f99f5_row3_col14, #T_f99f5_row3_col15, #T_f99f5_row3_col16, #T_f99f5_row3_col17, #T_f99f5 ...

# %% [markdown]
# ## Step 4: Create the Experiment Slice
#
# The following creates a single node with basic compute capabilities. You build a slice by creating a new slice and adding resources to the slice. After you build the slice, you must submit a request for the slice to be instantiated.
#
# By default, the submit function will block until the node is ready and will display the progress of your slice being built.
#
#
# <img src="./figs/SingleNode.png" width="20%"><br>

# %%
# Create a slice
slice = fablib.new_slice(name="MySlice")

# Add a node
node = slice.add_node(name="Node1")

# Submit the slice
slice.submit();
# Out:
# Retry: 8, Time: 182 sec
# <style type="text/css">
# #T_2d4aa tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_2d4aa tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_2d4aa caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_2d4aa_row0_col0, #T_2d4aa_row0_col1, #T_2d4aa_row1_col0, #T_2d4aa_row1_col1, #T_2d4aa_row2_col0, #T_2d4aa_row2_col1, #T_2d4aa_row3_col0, #T_2d4aa_row3_col1, #T_2d4aa_row4_col0, #T_2d4aa_row4_col1, #T_2d4aa_row5_col0, #T_2d4aa_row6_col0, #T_2d4aa_row6_col1, #T_2d4aa_row7_col0, #T_2d4aa_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_2d4aa_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_2d4aa">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2d4aa_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_2d4aa_row0_col1" class="data row0 col1" >c8758080-6e31-4e9a-a4f6-9ed66a446191</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_2d4aa_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_2d4aa_row2_col1" class="data row2 col1" >2026-03-27 21:02:13 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_2d4aa_row3_col1" class="data row3 col1" >2026-03-26 21:02:13 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_2d4aa_row4_col1" class="data row4 col1" >8b6dfc51-02ad-4f00-a389-6e75d8b61a26</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_2d4aa_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_2d4aa_row6_col1" class="data row6 col1" >lngo@wcupa.edu</td>
#     </tr>
#     <tr>
#       <td id="T_2d4aa_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_2d4aa_row7_col1" class="data row7 col1" >8eecd713-fa8f-4b3b-8883-1ff9b021fa53</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_62b1e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_62b1e th {
#   text-align: left;
# }
# #T_62b1e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_62b1e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_62b1e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_62b1e_row0_col0, #T_62b1e_row0_col1, #T_62b1e_row0_col2, #T_62b1e_row0_col3, #T_62b1e_row0_col4, #T_62b1e_row0_col5, #T_62b1e_row0_col6, #T_62b1e_row0_col7, #T_62b1e_row0_col8, #T_62b1e_row0_col9, #T_62b1e_row0_col10, #T_62b1e_row0_col13, #T_62b1e_row0_col14, #T_62b1e_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_62b1e_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_62b1e_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_62b1e">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_62b1e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_62b1e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_62b1e_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_62b1e_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_62b1e_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_62b1e_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_62b1e_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_62b1e_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_62b1e_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_62b1e_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_62b1e_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_62b1e_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_62b1e_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_62b1e_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_62b1e_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_62b1e_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62b1e_row0_col0" class="data row0 col0" >fcf0ec76-e09b-487f-81d8-e63e7461b0c9</td>
#       <td id="T_62b1e_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_62b1e_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_62b1e_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_62b1e_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_62b1e_row0_col5" class="data row0 col5" >default_rocky_9</td>
#       <td id="T_62b1e_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_62b1e_row0_col7" class="data row0 col7" >max-w1.fabric-testbed.net</td>
#       <td id="T_62b1e_row0_col8" class="data row0 col8" >MAX</td>
#       <td id="T_62b1e_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_62b1e_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_62b1e_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_62b1e_row0_col12" class="data row0 col12" ></td>
#       <td id="T_62b1e_row0_col13" class="data row0 col13" >ssh -i /home/fabric/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@None</td>
#       <td id="T_62b1e_row0_col14" class="data row0 col14" >/home/fabric/.ssh/slice_key.pub</td>
#       <td id="T_62b1e_row0_col15" class="data row0 col15" >/home/fabric/.ssh/slice_key</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 5: Observe the Slice's Attributes
#
# ### Show the slice attributes

# %%
slice.show();
# Out:
# <style type="text/css">
# #T_1e0de tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1e0de tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1e0de caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1e0de_row0_col0, #T_1e0de_row0_col1, #T_1e0de_row1_col0, #T_1e0de_row1_col1, #T_1e0de_row2_col0, #T_1e0de_row2_col1, #T_1e0de_row3_col0, #T_1e0de_row3_col1, #T_1e0de_row4_col0, #T_1e0de_row4_col1, #T_1e0de_row5_col0, #T_1e0de_row5_col1, #T_1e0de_row6_col0, #T_1e0de_row6_col1, #T_1e0de_row7_col0, #T_1e0de_row7_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1e0de">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1e0de_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_1e0de_row0_col1" class="data row0 col1" >c8758080-6e31-4e9a-a4f6-9ed66a446191</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_1e0de_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_1e0de_row2_col1" class="data row2 col1" >2026-03-27 21:02:13 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_1e0de_row3_col1" class="data row3 col1" >2026-03-26 21:02:13 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_1e0de_row4_col1" class="data row4 col1" >8b6dfc51-02ad-4f00-a389-6e75d8b61a26</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_1e0de_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row6_col0" class="data row6 col0" >Email</td>
#       <td id="T_1e0de_row6_col1" class="data row6 col1" >lngo@wcupa.edu</td>
#     </tr>
#     <tr>
#       <td id="T_1e0de_row7_col0" class="data row7 col0" >UserId</td>
#       <td id="T_1e0de_row7_col1" class="data row7 col1" >8eecd713-fa8f-4b3b-8883-1ff9b021fa53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If the slice attributes do not show a management ip, run the following cell to refresh configuration. Repeat until a management ip show up!

# %%
slice.update()

print("Slice state:", slice.get_state())
print("Slice stable:", slice.isStable())

for node in slice.get_nodes():
    print("----", node.get_name(), "----")
    print("reservation state:", node.get_reservation_state())
    print("management ip:", node.get_management_ip())
    print("username:", node.get_username())
    print("error:", node.get_error_message())
# Out:
# Slice state: StableOK
# Slice stable: True
# ---- Node1 ----
# reservation state: Active
# management ip: 2001:468:c00:ffc4:f816:3eff:fe4a:2cea
# username: rocky
# error:

# %% [markdown]
# ### List the nodes

# %%
slice.list_nodes();
# Out:
# <style type="text/css">
# #T_7c087 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7c087 th {
#   text-align: left;
# }
# #T_7c087 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7c087 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7c087 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7c087_row0_col0, #T_7c087_row0_col1, #T_7c087_row0_col2, #T_7c087_row0_col3, #T_7c087_row0_col4, #T_7c087_row0_col5, #T_7c087_row0_col6, #T_7c087_row0_col7, #T_7c087_row0_col8, #T_7c087_row0_col9, #T_7c087_row0_col10, #T_7c087_row0_col11, #T_7c087_row0_col12, #T_7c087_row0_col13, #T_7c087_row0_col14, #T_7c087_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7c087">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_7c087_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_7c087_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_7c087_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_7c087_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_7c087_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_7c087_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_7c087_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_7c087_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_7c087_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_7c087_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_7c087_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_7c087_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_7c087_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_7c087_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_7c087_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_7c087_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7c087_row0_col0" class="data row0 col0" >fcf0ec76-e09b-487f-81d8-e63e7461b0c9</td>
#       <td id="T_7c087_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_7c087_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_7c087_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_7c087_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_7c087_row0_col5" class="data row0 col5" >default_rocky_9</td>
#       <td id="T_7c087_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_7c087_row0_col7" class="data row0 col7" >max-w1.fabric-testbed.net</td>
#       <td id="T_7c087_row0_col8" class="data row0 col8" >MAX</td>
#       <td id="T_7c087_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_7c087_row0_col10" class="data row0 col10" >2001:468:c00:ffc4:f816:3eff:fe4a:2cea</td>
#       <td id="T_7c087_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_7c087_row0_col12" class="data row0 col12" ></td>
#       <td id="T_7c087_row0_col13" class="data row0 col13" >ssh -i /home/fabric/.ssh/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:468:c00:ffc4:f816:3eff:fe4a:2cea</td>
#       <td id="T_7c087_row0_col14" class="data row0 col14" >/home/fabric/.ssh/slice_key.pub</td>
#       <td id="T_7c087_row0_col15" class="data row0 col15" >/home/fabric/.ssh/slice_key</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 6: Run the Experiment
#
# Most experiments will require automated configuration and execution. You can use the fablib library to execute arbitrary commands on your node.
#
# The following code demonstrates how to use fablib to execute a "Hello, FABRIC" bash script. The library uses the bastion and VM keys defined at the top of this notebook to jump through the bastion host and execute the script.

# %%
#node = slice.get_node('Node1')
 
for node in slice.get_nodes():
    stdout, stderr = node.execute('echo Hello, FABRIC from node `hostname -s`')
# Out:
# Hello, FABRIC from node Node1

# %% [markdown]
# ## Step 7: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
slice.delete()
